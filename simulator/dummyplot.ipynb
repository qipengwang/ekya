# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import numpy as np
import matplotlib

# %matplotlib notebook
matplotlib.rcParams['figure.figsize'] = (6.0, 5)

# %%
plt.figure()
data_baseline = [(25,0), (25,200), [88,200], [88,300]]
data_baseline_mean = [(46,0), (46,300)]

data_baseline = [(25,0), (25,200), (25,200), [88,200], [88,300]]
data_baseline_mean = [(46,0), (46,300)]

y_data, x_data = list(zip(*data_baseline))
plt.plot(x_data, y_data, 'b-', label='Baseline Accuracy')
y_data, x_data = list(zip(*data_baseline_mean))
plt.plot(x_data, y_data, 'b--', label='Baseline Mean Accuracy')

plt.ylim([0,100])
plt.xlabel("Time")
plt.ylabel("Accuracy")
plt.title("Single Job Baseline - Picking eventually best hyperparameters")
plt.legend()
plt.savefig("single_baseline.png", dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
plt.figure()
data = [(25,0), (25,50), [79, 50], [79,300]]
data_mean = [(70,0), (70,300)]

y_data, x_data = list(zip(*data))
plt.plot(x_data, y_data, 'r-', label='Our Accuracy')
y_data, x_data = list(zip(*data_mean))
plt.plot(x_data, y_data, 'r--', label='Our Mean Accuracy')

plt.ylim([0,100])
plt.xlabel("Time")
plt.ylabel("Accuracy")
plt.title("Single Job Our - picking faster hyperparameters")
plt.legend()
plt.savefig("single_us.png", dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # Multi Model

# %%
plt.figure()
contention_acc = 12.5
cs = 0.5 # contention slowdown
A_post_acc = 79
A_train_time = 25
A_mean_acc = 63.96

B_post_acc = 65
B_train_time = 15
B_mean_acc = 51

total_time = 300

data_A = [(contention_acc, 0), (contention_acc, A_train_time),
          [A_post_acc*cs, A_train_time], [A_post_acc*cs, A_train_time+B_train_time],
          [A_post_acc, A_train_time+B_train_time], [A_post_acc, total_time]]
data_A_mean = [(A_mean_acc,0), (A_mean_acc,300)]

data_B = [(contention_acc, 0), (contention_acc, B_train_time + A_train_time),
          [B_post_acc, A_train_time+B_train_time], [B_post_acc, total_time]]
data_B_mean = [(B_mean_acc,0), (B_mean_acc,300)]

y_data, x_data = list(zip(*data_A))
plt.plot(x_data, y_data, 'b-', label='Model A Accuracy')
y_data, x_data = list(zip(*data_A_mean))
plt.plot(x_data, y_data, 'b--', label='Model A Mean Accuracy')

y_data, x_data = list(zip(*data_B))
plt.plot(x_data, y_data, 'r-', label='Model B Accuracy')
y_data, x_data = list(zip(*data_B_mean))
plt.plot(x_data, y_data, 'r--', label='Model B Mean Accuracy')

plt.ylim([0,100])
plt.xlabel("Time")
plt.ylabel("Accuracy")
plt.title("Multi Job Our - A allocated more resources than B")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
plt.figure()
contention_acc = 12.5
cs = 0.5 # contention slowdown
A_post_acc = 88
A_train_time = 100
A_mean_acc = 23

B_post_acc = 80
B_train_time = 300
B_mean_acc = 12.5

total_time = 300

data_A = [(contention_acc, 0), (contention_acc, A_train_time),
          [A_post_acc*cs, A_train_time], [A_post_acc*cs, total_time]]
data_A_mean = [(A_mean_acc,0), (A_mean_acc,300)]

data_B = [(contention_acc, 0), (contention_acc, total_time)]
data_B_mean = [(B_mean_acc,0), (B_mean_acc,300)]

y_data, x_data = list(zip(*data_A))
plt.plot(x_data, y_data, 'b-', label='Model A Accuracy')
y_data, x_data = list(zip(*data_A_mean))
plt.plot(x_data, y_data, 'b--', label='Model A Mean Accuracy')

y_data, x_data = list(zip(*data_B))
plt.plot(x_data, y_data, 'r-', label='Model B Accuracy')
y_data, x_data = list(zip(*data_B_mean))
plt.plot(x_data, y_data, 'r--', label='Model B Mean Accuracy')

plt.ylim([0,100])
plt.xlabel("Time")
plt.ylabel("Accuracy")
plt.title("Multi Job Baseline - B is never exploited")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
plt.figure()
contention_acc = 12.5
cs = 0.5 # contention slowdown
A_post_acc = 84
A_train_time = 140
A_mean_acc = 36.63

B_post_acc = 71
B_train_time = 400
B_mean_acc = 24.2

total_time = 300

data_A = [(contention_acc, 0), (contention_acc, A_train_time),
          [A_post_acc*cs, A_train_time], [A_post_acc*cs, A_train_time+B_train_time],
          [A_post_acc, A_train_time+B_train_time], [A_post_acc, total_time]]
data_A_mean = [(A_mean_acc,0), (A_mean_acc,300)]

data_B = [(contention_acc, 0), (contention_acc, B_train_time + A_train_time),
          [B_post_acc, A_train_time+B_train_time], [B_post_acc, total_time]]
data_B_mean = [(B_mean_acc,0), (B_mean_acc,300)]

y_data, x_data = list(zip(*data_A))
plt.plot(x_data, y_data, 'b-', label='Model A Accuracy')
y_data, x_data = list(zip(*data_A_mean))
plt.plot(x_data, y_data, 'b--', label='Model A Mean Accuracy')

y_data, x_data = list(zip(*data_B))
plt.plot(x_data, y_data, 'r-', label='Model B Accuracy')
y_data, x_data = list(zip(*data_B_mean))
plt.plot(x_data, y_data, 'r--', label='Model B Mean Accuracy')

plt.ylim([0,100])
plt.xlabel("Time")
plt.ylabel("Accuracy")
plt.title("Multi Job Baseline - independently best hyperparameters")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="600">
